# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# ## Task 1

# %% [markdown]
# You are a member of an international team analysing environmental pollution. The project involves ten cities: Cairo, Dhaka, Jakarta, Karachi, Manila, Melbourne, Osaka, Shanghai, Singapore, and Tokyo.
#
# Your task is to process and organise data from various environmental measurements. The provided zip file, os-collaboration-exercise-data.zip, contains all relevant data files for the past year.
#
# Things to note
#
# Data Files: Each data file is named in the format month-date_city.txt (e.g., may-10_singapore.txt).
# Data Collection: Data was recorded sporadically; not all days of each month have corresponding data files. The dates of data collection vary across the cities.
# Exclusion of Files: Ignore any non-text files, such as those in .pdf, .png, or .jpg formats.

# %%
We like to convert the filename to a more useful numerical format. Specifically, we want to convert month-date-city.txt. 
(i.e. may-10-singapore.txt) to a mm-dd-city.txt (i.e. 05-10-singapore.txt) format.

Using the following dictionary (or otherwise), write a snippet of Python code to convert 'oct-08_singapore.txt' to 10-08-singapore.txt.

{
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

# %%
{
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}
# Out:
# {'jan': '01',
#  'feb': '02',
#  'mar': '03',
#  'apr': '04',
#  'may': '05',
#  'jun': '06',
#  'jul': '07',
#  'aug': '08',
#  'sep': '09',
#  'oct': '10',
#  'nov': '11',
#  'dec': '12'}

# %%
import os

# %%
import glob

# %%
import shutil

# %%
conversion = { 
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
}

# %%
conversion['oct']
# Out:
# '10'

# %%
filename = 'oct-08_singapore.txt'
months = filename[0:3]
underscore = filename[6]
filename.replace(months,conversion['oct']).replace(underscore,'-')
# Out:
# '10-08-singapore.txt'

# %% [markdown]
# ## Task 2

# %%
Incorporate your previous code into a function named rename_my_file(old_file_name) that accepts the old filename as the 
argument and returns the new file name.

# %%
conversion = { 
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

# %%
def rename_my_file(old_file_name):
    months = old_file_name[0:3]
    underscore = old_file_name[6]
    new_file_name = old_file_name.replace(months, conversion[months]).replace(underscore, '-')
    return new_file_name

# %%
rename_my_file('oct-08_singapore.txt')
# Out:
# '10-08-singapore.txt'

# %%
rename_my_file('jan-08_singapore.txt')
# Out:
# '01-08-singapore.txt'

# %% [markdown]
# ## Task 3

# %%
Use a for loop to apply the function rename_my_file() to the file list below.

['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

Print out your progress in the form old-file-name ----> new-file-name

# %%
toberenamed = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for old_file_name in toberenamed:
    print(f'{old_file_name} ----> {rename_my_file(old_file_name)}')
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# ## Task 4

# %%
With the help of glob, use rename_my_file() to rename all the .txt files in the folder.

Note that you might have to adjust your function rename_my_file() to accommodate the already renamed files.

# %%
glob.glob('os-collaboration-exercise-data/*txt')
# Out:
# ['os-collaboration-exercise-data/dec-10_osaka.txt',
#  'os-collaboration-exercise-data/jul-14_karachi.txt',
#  'os-collaboration-exercise-data/nov-17_osaka.txt',
#  'os-collaboration-exercise-data/jul-13_cairo.txt',
#  'os-collaboration-exercise-data/jun-15_manila.txt',
#  'os-collaboration-exercise-data/aug-20_tokyo.txt',
#  'os-collaboration-exercise-data/jun-16_melbourne.txt',
#  'os-collaboration-exercise-data/sep-05_tokyo.txt',
#  'os-collaboration-exercise-data/jun-22_manila.txt',
#  'os-collaboration-exercise-data/apr-11_shanghai.txt',
#  'os-collaboration-exercise-data/sep-21_singapore.txt',
#  'os-collaboration-exercise-data/feb-01_singapore.txt',
#  'os-collaboration-exercise-data/may-09_manila.txt',
#  'os-collaboration-exercise-data/jan-20_tokyo.txt',
#  'os-collaboration-exercise-data/jan-30_manila.txt',
#  'os-collaboration-exercise-data/jun-28_tokyo.txt',
#  'os-collaboration-exercise-data/apr-16_shanghai.txt',
#  'os-collaboration-exercise-data/dec-07_shanghai.txt',
# ...

# %%
conversion= {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

directory = glob.glob('os-collaboration-exercise-data/*txt', recursive=True)

for files in directory:
    old_file_name = files.replace('os-collaboration-exercise-data/','')
    current_path = os.path.join('.','os-collaboration-exercise-data/', old_file_name)
    new_path = os.path.join('.','os-collaboration-exercise-data/', rename_my_file(old_file_name))
    shutil.move(current_path, new_path)

# %%
glob.glob('os-collaboration-exercise-data/**/*.txt', recursive=True) #NO WAY I DID IT
# Out:
# ['os-collaboration-exercise-data/07-28-dhaka.txt',
#  'os-collaboration-exercise-data/10-16-shanghai.txt',
#  'os-collaboration-exercise-data/10-18-dhaka.txt',
#  'os-collaboration-exercise-data/09-18-cairo.txt',
#  'os-collaboration-exercise-data/12-15-melbourne.txt',
#  'os-collaboration-exercise-data/07-09-shanghai.txt',
#  'os-collaboration-exercise-data/04-05-singapore.txt',
#  'os-collaboration-exercise-data/04-06-cairo.txt',
#  'os-collaboration-exercise-data/05-02-osaka.txt',
#  'os-collaboration-exercise-data/07-07-osaka.txt',
#  'os-collaboration-exercise-data/01-01-osaka.txt',
#  'os-collaboration-exercise-data/10-11-shanghai.txt',
#  'os-collaboration-exercise-data/08-08-melbourne.txt',
#  'os-collaboration-exercise-data/10-26-jakarta.txt',
#  'os-collaboration-exercise-data/08-20-tokyo.txt',
#  'os-collaboration-exercise-data/03-04-osaka.txt',
#  'os-collaboration-exercise-data/08-02-jakarta.txt',
#  'os-collaboration-exercise-data/04-12-singapore.txt',
# ...

# %% [markdown]
# ## Exercise 5

# %%
Use a for loop to create a folder for each city.
The list of cities is provided below for your convenience.

['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
for city in ['cairo', 'dhaka', 'jakarta', 'karachi', 'manila', 'melbourne', 'osaka', 'shanghai', 'singapore', 'tokyo']:
    path = os.path.join('os-collaboration-exercise-data', city)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating os-collaboration-exercise-data/cairo
# Creating os-collaboration-exercise-data/dhaka
# Creating os-collaboration-exercise-data/jakarta
# Creating os-collaboration-exercise-data/karachi
# Creating os-collaboration-exercise-data/manila
# Creating os-collaboration-exercise-data/melbourne
# Creating os-collaboration-exercise-data/osaka
# Creating os-collaboration-exercise-data/shanghai
# Creating os-collaboration-exercise-data/singapore
# Creating os-collaboration-exercise-data/tokyo

# %% [markdown]
# ## Task 6

# %% [markdown]
# Use glob to list all the files from Cairo.
# Now use a for loop and shutil.copy() to copy all the files related to Cairo to the corresponding folder you created.

# %%
glob.glob('../**/*Cairo', recursive = True)
# Out:
# ['../6.2_files,_folders_&_os__exercises/Cairo',
#  '../6.2_files,_folders_&_os__exercises/cities/Cairo']

# %%
glob.glob("os-collaboration-exercise-data/*cairo.txt")
# Out:
# ['os-collaboration-exercise-data/09-18-cairo.txt',
#  'os-collaboration-exercise-data/04-06-cairo.txt',
#  'os-collaboration-exercise-data/03-06-cairo.txt',
#  'os-collaboration-exercise-data/01-03-cairo.txt',
#  'os-collaboration-exercise-data/03-12-cairo.txt',
#  'os-collaboration-exercise-data/04-12-cairo.txt',
#  'os-collaboration-exercise-data/12-05-cairo.txt',
#  'os-collaboration-exercise-data/07-30-cairo.txt',
#  'os-collaboration-exercise-data/07-24-cairo.txt',
#  'os-collaboration-exercise-data/07-08-cairo.txt',
#  'os-collaboration-exercise-data/12-29-cairo.txt',
#  'os-collaboration-exercise-data/08-07-cairo.txt',
#  'os-collaboration-exercise-data/09-20-cairo.txt',
#  'os-collaboration-exercise-data/08-26-cairo.txt',
#  'os-collaboration-exercise-data/07-29-cairo.txt',
#  'os-collaboration-exercise-data/12-03-cairo.txt',
#  'os-collaboration-exercise-data/01-30-cairo.txt',
#  'os-collaboration-exercise-data/12-17-cairo.txt',
# ...

# %%
for file in glob.glob("os-collaboration-exercise-data/*cairo.txt"):
    pathcario = os.path.join('os-collaboration-exercise-data','cairo')
    shutil.copy(file, pathcario)
    print(f'Copied file to {pathcario}')
# Out:
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# Copied file to os-collaboration-exercise-data/cairo
# ...

# %% [markdown]
# ## Task 7

# %% [markdown]
# Tweak your code to move all the files to the corresponding folders of all the cities.

# %%
for city in ['cairo', 'dhaka', 'jakarta', 'karachi', 'manila', 'melbourne', 'osaka', 'shanghai', 'singapore', 'tokyo']:
    for file in glob.glob(f'os-collaboration-exercise-data/*{city}.txt'):
        pathcity = os.path.join('os-collaboration-exercise-data',city,file.split(os.path.sep)[-1]) #use split to separate filename
        if os.path.exists(pathcity) == True:
            print('file already exists')
        else: 
            shutil.move(file, pathcity)
            print(f'Moved file to {pathcity}')
# Out:
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# ...

# %% [markdown]
# # IGNORE THIS PLS

# %%
with open('os-collaboration-exercise-data/08-03-cairo.txt', 'r') as file:
    file_content = file.read()

print(file_content)
# Out:
# 1:39:07 AM	8090.86
# 12:49:45 PM	8365.94
# 6:18:18 PM	3252.45
# 3:28:37 AM	5246.24
# 11:02:40 PM	3140.12
# 5:18:24 PM	2107.62
# 6:00:00 AM	3189.35
# 11:04:57 PM	6704.97
# 7:30:15 PM	3459.44
# 4:48:15 AM	3520.55
# 5:38:43 PM	4815.24
# 10:23:25 PM	2825.63
# 5:08:27 AM	8261.26
# 3:50:03 PM	1742.21
# 9:14:22 AM	3248.64
# 6:13:13 AM	9375.24
# 5:13:47 AM	3275.13
# 7:27:25 AM	585.53
# 11:25:38 AM	9598.57
# 7:24:17 PM	5473.75
# 1:59:02 AM	6383.99
# 11:07:13 AM	4145.84
# 11:04:52 AM	3104.79
# 11:37:13 AM	8829.98
# 9:41:15 AM	2518.26
# 7:00:15 AM	7915.73
# 11:58:53 PM	5035.75
# 1:47:59 PM	8985.32
# 4:41:58 PM	2807.78
# 7:48:00 AM	407.67
# 5:57:25 AM	9344.48
# 1:20:53 PM	3565.26
# 5:33:46 AM	2991.54
# 11:10:12 PM	284.37
# 9:31:52 AM	5082.17
# 2:32:55 PM	2538.73
# 5:52:08 PM	6085.18
# 1:28:23 AM	3997.14
# 12:41:24 AM	5569.65
# 12:29:24 PM	5485.24
# 5:01:21 AM	4306.4
# 5:55:08 PM	8931.82

# %%
test = glob.glob('os-collaboration-exercise-data/*cairo.txt')[0]

# %%
test
# Out:
# 'os-collaboration-exercise-data/09-18-cairo.txt'

# %%
path = test
filename = path.split(os.path.sep)[-1]
extension = filename.split('.')[-1]
print(filename)
# Out:
# 09-18-cairo.txt

# %%
cities= ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila', 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
for city in cities:
    pathcity = os.path.join('cities', city)
    os.makedirs(pathcity, exist_ok=True)  # Create the directory if it doesn't exist

    # Find files containing the city name
    for file in glob.glob(f'os-collaboration-exercise-data/*{city}.txt'):
        shutil.move(file, pathcity)  # Move file instead of copying
        print(f'Moved {file} to {pathcity}')

# %%
for city in ['Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']: #Cairo files alr moved into the Cairo folder
    for file in glob.glob(f'**\\*{city}*'):
        try:
            path_city = os.path.join('.', 'cities', city)
            shutil.move(file, path_city)
            print(f'Moved file to {path_city}')
        except PermissionError:
            print(f'this is a {city} folder')
